# %%
# %load_ext autoreload
# %autoreload 2
sys.path.insert(0, "../timeseries/")

# %%
#from explore import 
from explore import (
    plot_series_abs, plot_series_rel 
)
import pandas as pd

# %%
coin_returns = pd.read_csv("coins.csv", index_col="date")
coin_returns.index = pd.to_datetime(coin_returns.index, utc=True)
series = coin_returns["frax"].dropna()

# %%
pd.DataFrame(series)
# Out:
#                                frax
# date
# 2020-12-21 00:00:00+00:00  0.975081
# 2020-12-22 00:00:00+00:00  0.975081
# 2020-12-23 00:00:00+00:00  1.001050
# 2020-12-24 00:00:00+00:00  0.991596
# 2020-12-25 00:00:00+00:00  0.999803
# ...                             ...
# 2022-07-03 00:00:00+00:00  0.999813
# 2022-07-04 00:00:00+00:00  0.995538
# 2022-07-05 00:00:00+00:00  0.998632
# 2022-07-06 00:00:00+00:00  0.998313
# 2022-07-07 00:00:00+00:00  0.999344
#
# [564 rows x 1 columns]

# %%
plot_series_abs(series)

# %%
plot_series_rel(series)

# %%
print("Observations: " +str(len(series.values)))
print("First: "+str(round(series.values[1],4)))
print("Last: "+str(round(series.values[-1],4)))
# Out:
# Observations: 564
# First: 0.9751
# Last: 0.9993
